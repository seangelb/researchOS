# %% [markdown]
# # Explore official gaming revenue
# Start here. Change the variables below, then **Restart Kernel and Run All**.
# This notebook reads local SQLite data. It does not download, migrate, or write to the database.
# CSV export at the end is optional and disabled by default.

# %%
database_file = "data/staging/gaming_nationwide.sqlite"  # or "data/gaming.sqlite"
states = None  # None = every state present in gaming_results; or e.g. ["MA", "NJ"]
product = "online_sports_betting"  # or "online_casino"
metric = "gross_revenue"  # adjusted_revenue, taxable_revenue, net_proceeds, handle, tax
start_date = "2025-01-01"
end_date = None  # None means the latest stored period
frequency = "monthly"  # or "weekly"; weeks are never turned into months
channel = "online"
growth_states_reviewed = []  # [] skips until reviewed; or e.g. ["MA", "NJ"] after reading reports
# None also skips (does not approve all states). Only an explicit list calculates YoY.

# %% [markdown]
# ## 1. Read local data
# One database holds the observations and their source references. Each file hash is retained.
# Equal copies collapse for analysis. If reports disagree, their values stay unselected until reviewed.

# %%
from pathlib import Path
import sys

import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display

ROOT = Path.cwd()
if (ROOT / "gaming" / "src").is_dir():
    ROOT = ROOT / "gaming"
if not (ROOT / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))

from variant_gaming.consolidate import MONEY_COLUMNS, build_state_period_revenue, build_source_coverage_export
from variant_gaming.storage import connect_readonly

database_path = ROOT / database_file
print(f"Reading: {database_path}")
connection = connect_readonly(database_path)
try:
    results = pd.read_sql_query("SELECT * FROM gaming_results", connection)
    coverage = build_source_coverage_export(connection, ROOT)
finally:
    connection.close()
inventory = pd.read_csv(ROOT / "config/state_gaming_source_inventory.csv").fillna("")
metric_notes = pd.read_csv(ROOT / "config/state_metric_notes.csv").fillna("unknown")
# Out:
# Reading: c:\Users\Sean\VscProjects\researchOS\data\staging\gaming_nationwide.sqlite

# %%
if states is None:
    states = sorted(results["state_code"].dropna().astype(str).str.upper().unique())
else:
    states = list(dict.fromkeys(state.upper() for state in states))
    unknown = set(states) - set(coverage["state_code"])
    if not states or unknown:
        raise ValueError(f"Choose inventory states; unknown={sorted(unknown)}")
# None and [] both skip YoY. Never auto-approve all selected states.
growth_states_reviewed = (
    [] if growth_states_reviewed is None
    else list(dict.fromkeys(state.upper() for state in growth_states_reviewed))
)
if metric not in MONEY_COLUMNS:
    raise ValueError(f"Choose a metric from {MONEY_COLUMNS}")
if product not in {"online_sports_betting", "online_casino"}:
    raise ValueError("Choose online_sports_betting or online_casino")
if frequency not in {"monthly", "weekly"}:
    raise ValueError("Choose monthly or weekly")
start = pd.Timestamp(start_date)
end = pd.Timestamp(end_date) if end_date else pd.Timestamp(results["period_end"].max())
if start > end:
    raise ValueError("start_date must be on or before end_date")

# %% [markdown]
# ## 2. Read the definitions before comparing
# The inventory is a dated source-research snapshot. Its counts/ranges refer to the staging database.
# The stored coverage table below describes the database you selected. Neither proves complete history.
#
# Read the notes for the **selected metric**, especially timing, promotions and other deductions.
# An unknown definition date means the example has not been shown to apply to all historical periods.
# Connecticut and Pennsylvania have corrected mappings in staging; the original database keeps its older values.
#
# - State growth needs the same period, channel and financial definition, including deduction rules.
# - Cross-state totals need compatible definitions and a disclosed list of included states. No national total is calculated here.
# - Hold needs matching wager and revenue definitions. Illinois uses different timing bases; Pennsylvania casino wagers omit poker volume.
# - Market share needs matching operator identities and a complete denominator. Licensees are not automatically brands.
# - Revenue-only analysis can proceed without handle. Missing values and source conflicts remain visible.

# %%
source_notes = inventory[inventory.state_code.isin(states) & inventory.vertical.eq(product)]
display(source_notes[["state_code", "collection_status", "source_checked_at_utc", "channel_coverage", "status_note", "next_action"]])
definitions = metric_notes[metric_notes.state_code.isin(states) & metric_notes.vertical.eq(product)
                          & metric_notes.storage_column.isin([metric, "none"])]
display(definitions[["state_code", "source_label", "definition", "timing_basis", "promotions_and_deductions",
                     "reporting_frequency", "definition_applies_from", "definition_applies_to", "evidence_period", "source_url"]])

selected_coverage = coverage[
    coverage["state_code"].isin(states) & coverage["vertical"].eq(product)
]
display(selected_coverage[["state_code", "status", "earliest_period", "latest_period", "reason", "official_url"]])

selected = results[results["state_code"].isin(states) & results["vertical"].eq(product)].copy()
analysis_rows = selected.copy()
# The preserved database predates these mapping repairs. Keep its raw rows in the trace.
if database_path.resolve() == (ROOT / "data/gaming.sqlite").resolve():
    needs_replay = (["CT"] if metric == "gross_revenue" else
                    ["NJ"] if metric in {"tax", "taxable_revenue"} else [])
    analysis_rows.loc[analysis_rows.state_code.isin(needs_replay), metric] = float("nan")
    if set(needs_replay) & set(states):
        print("Use staging for the corrected CT gross or NJ tax fields; original values are excluded.")
period_rows = build_state_period_revenue(analysis_rows, metric=metric)
period_rows["period_start"] = pd.to_datetime(period_rows["period_start"])
period_rows["period_end"] = pd.to_datetime(period_rows["period_end"])
in_window = period_rows["period_start"].ge(start) & period_rows["period_end"].le(end)
requested = period_rows[in_window & period_rows["frequency"].eq(frequency) & period_rows["channel"].eq(channel)].copy()
# Out:
#     state_code        collection_status source_checked_at_utc  \
# 10          CO      partially_collected            2026-09-05
# 12          CT  collected_and_validated            2026-09-05
# 14          DC      partially_collected            2026-09-05
# 16          DE  combined_reporting_only            2026-09-05
# 24          IA  collected_and_validated            2026-09-05
# 28          IL  collected_and_validated            2026-09-05
# 30          IN  collected_and_validated            2026-09-05
# 32          KS      partially_collected            2026-09-05
# 34          KY      partially_collected            2026-09-05
# 36          LA      partially_collected            2026-09-05
# 38          MA  collected_and_validated            2026-09-05
# 40          MD  collected_and_validated            2026-09-05
# 42          ME  collected_and_validated            2026-09-05
# 44          MI  collected_and_validated            2026-09-05
# 48          MO  collected_and_validated            2026-09-05
# 54          NC  collected_and_validated            2026-09-05
# 60          NH  collected_and_validated            2026-09-05
# 62          NJ      partially_collected            2026-09-05
# 66          NV      partially_collected            2026-09-05
# 68          NY  collected_and_validated            2026-09-05
# 70          OH  collected_and_validated            2026-09-05
# 74          OR      partially_collected            2026-09-05
# 76          PA  collected_and_validated            2026-09-05
# 78          RI  collected_and_validated            2026-09-05
# 84          TN  collected_and_validated            2026-09-05
# 92          VT  collected_and_validated            2026-09-05
# 98          WV  collected_and_validated            2026-09-05
# 100         WY      partially_collected            2026-09-05
#
#                channel_coverage  \
# 10                       online
# 12                       online
# 14                       online
# 16   mobile and retail combined
# 24                       online
# 28                       online
# 30                       online
# 32                       online
# 34                       online
# 36                       online
# 38                       online
# 40                       online
# 42                       online
# 44                       online
# 48                       online
# 54                       online
# 60                       online
# 62                       online
# 66                       online
# 68                       online
# 70                       online
# 74                       online
# 76                       online
# 78                       online
# 84                       online
# 92                       online
# 98                       online
# 100                      online
#
#                                            status_note  \
# 10   Archive is July 2021-February 2026 with July 2...
# 12   Staging corrects the legacy mapping: printed o...
# 14   Stored official history starts July 2024; earl...
# 16   Official lottery sportsbook tables group casin...
# 24   Retained official reports parsed with state-sp...
# 28   Handle uses all wagering activity while State ...
# 30   Legacy calculated totals remain classified as ...
# 32   Current detail archive starts January 2023; Se...
# 34   Only March-April 2025 statewide online figures...
# 36   FY22 workbook final two rows print July/August...
# 38   Settled wagers and Accrual Win are distinct fr...
# 40   Archive pagination and older release titles ar...
# 42   Two native tribal reporting groups; operator s...
# 44   Retained official reports parsed with state-sp...
# 48   Retained official reports parsed with state-sp...
# 54   Retained official reports parsed with state-sp...
# 60   Retained official reports parsed with state-sp...
# 62   Sports handle is missing. The 98 retained spor...
# 66   Mobile-only win starts January 2020 in this ar...
# 68   Weekly cash-basis mobile handle/GGR; overlappi...
# 70   Retained official reports parsed with state-sp...
# 74   Public commission archive is rolling; currentl...
# 76   Staging replays original sports workbooks and ...
# 78   Retained official reports parsed with state-sp...
# 84   Current series is handle and privilege tax, no...
# 92   Monthly source reports January 2024 onward; tw...
# 98   Weekly periods remain as reported. Casino Reve...
# 100  Historical statewide summaries become operator...
#
#                                            next_action
# 10   Use notebook 90 to check the requested metric,...
# 12   Use notebook 90 to check the requested metric,...
# 14   Use notebook 90 to check the requested metric,...
# 16   Obtain separately labeled online activity and ...
# 24   Use notebook 90 to check the requested metric,...
# 28   Use notebook 90 to check the requested metric,...
# 30   Use notebook 90 to check the requested metric,...
# 32   Use notebook 90 to check the requested metric,...
# 34   Use notebook 90 to check the requested metric,...
# 36   Use notebook 90 to check the requested metric,...
# 38   Use notebook 90 to check the requested metric,...
# 40   Use notebook 90 to check the requested metric,...
# 42   Use notebook 90 to check the requested metric,...
# 44   Use notebook 90 to check the requested metric,...
# 48   Use notebook 90 to check the requested metric,...
# 54   Use notebook 90 to check the requested metric,...
# 60   Use notebook 90 to check the requested metric,...
# 62   Use notebook 90 to check the requested metric,...
# 66   Use notebook 90 to check the requested metric,...
# 68   Use notebook 90 to check the requested metric,...
# 70   Use notebook 90 to check the requested metric,...
# 74   Use notebook 90 to check the requested metric,...
# 76   Use notebook 90 to check the requested metric,...
# 78   Use notebook 90 to check the requested metric,...
# 84   Use notebook 90 to check the requested metric,...
# 92   Use notebook 90 to check the requested metric,...
# 98   Use notebook 90 to check the requested metric,...
# 100  Use notebook 90 to check the requested metric,...
#     state_code                                       source_label  \
# 11          CO                                 Total GGR - Online
# 16          CT  Online Sports Wagering Win/(Loss) / Online Cas...
# 25          DC                         Gross Gaming Revenue (GGR)
# 28          DE                                no collected metric
# 47          IN                                     Gross Receipts
# 64          MA                                        Accrual Win
# 77          MI                                     Gross Receipts
# 94          NC                             Gross Wagering Revenue
# 102         NH                                         Mobile GGR
# 105         NJ  Monthly Internet Sports Wagering Gross Revenue...
# 111         NV                        Sports - Mobile: Win Amount
# 114         NY                                                GGR
# 117         OH                                            Revenue
# 123         OR                               Net Revenue - Sports
# 126         PA          Revenue (sports) / Gross Revenue (casino)
# 133         RI  Book Revenue (sports) / Net Gaming Revenue (ca...
# 163         WY                               Gross Gaming Revenue
#
#                                             definition timing_basis  \
# 11   Printed online gross wagers less payments to p...      unknown
# 16   Printed online win/loss before federal excise ...      unknown
# 25   Native reported gaming win/receipts in this so...      unknown
# 28   Official lottery sportsbook tables group casin...      unknown
# 47   Native reported gaming win/receipts in this so...      unknown
# 64   Accrual Win from settled sports wagers, retain...      accrual
# 77   Native reported gaming win/receipts in this so...      unknown
# 94   Native reported gaming win/receipts in this so...      unknown
# 102  Native reported gaming win/receipts in this so...      unknown
# 105  Native reported gaming win/receipts in this so...      unknown
# 111  Current-month mobile sports win from the state...      unknown
# 114  Native reported gaming win/receipts in this so...         cash
# 117  Reported Revenue: total gross receipts less ca...      unknown
# 123  Sports gross receipts less sports prizes, befo...      unknown
# 126  Sports: printed Revenue before Promotional Cre...      unknown
# 133  Reported sports Book Revenue or combined iSlot...      accrual
# 163  Monthly Wagers less Cash Winnings Paid Out, pe...      unknown
#
#                              promotions_and_deductions reporting_frequency  \
# 11   NSBP includes allowed deductions; promotion al...             monthly
# 16   Gross and taxable/payment calculations differ....             monthly
# 25   unknown; inspect the linked report and applica...             monthly
# 28                                             unknown  accounting periods
# 47   unknown; inspect the linked report and applica...             monthly
# 64   Taxable revenue has promotional/other adjustme...             monthly
# 77   Adjusted Gross includes product-specific permi...             monthly
# 94   unknown; inspect the linked report and applica...             monthly
# 102  unknown; inspect the linked report and applica...             monthly
# 105  unknown; inspect the linked report and applica...             monthly
# 111  Promotion, futures and cash/settlement treatme...             monthly
# 114  Weekly cash-basis receipts and payouts; no con...              weekly
# 117  unknown; inspect the linked report and applica...             monthly
# 123  Printed prizes are subtracted before operating...             monthly
# 126  Sports Promotional Credits separate Revenue fr...             monthly
# 133  The source explicitly states accrual and unaud...             monthly
# 163  Net/taxable measures deduct non-cash winnings,...             monthly
#
#     definition_applies_from definition_applies_to           evidence_period  \
# 11                  unknown               unknown  2024-06-01 to 2024-06-30
# 16                  unknown               unknown  2026-07-01 to 2026-07-31
# 25                  unknown               unknown  2026-07-01 to 2026-07-31
# 28                  unknown               unknown                      none
# 47                  unknown               unknown  2026-07-01 to 2026-07-31
# 64                  unknown               unknown  2026-07-01 to 2026-07-31
# 77                  unknown               unknown  2026-07-01 to 2026-07-31
# 94                  unknown               unknown  2026-07-01 to 2026-07-31
# 102                 unknown               unknown  2026-07-01 to 2026-07-31
# 105                 unknown               unknown  2026-07-01 to 2026-07-31
# 111                 unknown               unknown  2026-07-01 to 2026-07-31
# 114                 unknown               unknown  2026-08-17 to 2026-08-23
# 117                 unknown               unknown  2026-07-01 to 2026-07-31
# 123                 unknown               unknown  2026-07-01 to 2026-07-31
# 126                 unknown               unknown  2026-07-01 to 2026-07-31
# 133                 unknown               unknown  2026-07-01 to 2026-07-31
# 163                 unknown               unknown  2026-07-01 to 2026-07-31
#
#                                             source_url
# 11   https://spl.cde.state.co.us/artemis/revserials...
# 16   https://data.ct.gov/api/views/xf6g-659c/rows.c...
# 25   https://dclottery.com/olg/financials/july-2026...
# 28   https://delottery.com/Sports-Lottery/Monthly-N...
# 47   https://www.in.gov/igc/files/reports/2026/2026...
# 64   https://massgaming.com/wp-content/uploads/MGC-...
# 77   https://www.michigan.gov/mgcb/-/media/Project/...
# 94   https://ncgaming.gov/wp-content/uploads/2026/0...
# 102  https://assets.ctfassets.net/1h4s33nxm7rw/M2se...
# 105  https://www.nj.gov/oag/ge/docs/Financials/SWRT...
# 111  https://www.gaming.nv.gov/siteassets/content/a...
# 114  https://gaming.ny.gov/system/files/documents/2...
# 117  https://dam.assets.ohio.gov/raw/upload/v178819...
# 123  https://www.oregonlottery.org/wp-content/uploa...
# 126  https://gamingcontrolboard.pa.gov/sites/defaul...
# 133  https://www.rilot.com/content/dam/interactive/...
# 163  https://drive.google.com/uc?export=download&id...
#     state_code                   status earliest_period latest_period  \
# 10          CO                       ok      2021-07-01    2026-02-28
# 12          CT  collected_and_validated      2021-10-01    2026-07-31
# 14          DC      partially_collected      2024-07-01    2026-07-31
# 16          DE  combined_reporting_only             NaN           NaN
# 24          IA  collected_and_validated      2019-08-01    2026-07-31
# 28          IL  collected_and_validated      2020-03-01    2026-06-30
# 30          IN  collected_and_validated      2019-10-01    2026-07-31
# 32          KS      partially_collected      2023-01-01    2026-07-31
# 34          KY      partially_collected      2025-03-01    2025-04-30
# 36          LA      partially_collected      2022-01-01    2026-07-31
# 38          MA  collected_and_validated      2023-03-01    2026-07-31
# 40          MD  collected_and_validated      2022-11-01    2026-07-31
# 42          ME  collected_and_validated      2023-11-01    2026-07-31
# 44          MI  collected_and_validated      2021-01-01    2026-07-31
# 48          MO  collected_and_validated      2025-12-01    2026-07-31
# 54          NC  collected_and_validated      2024-03-01    2026-07-31
# 60          NH  collected_and_validated      2019-12-01    2026-07-31
# 62          NJ      partially_collected      2018-06-01    2026-07-31
# 66          NV      partially_collected      2020-01-01    2026-07-31
# 68          NY  collected_and_validated      2022-01-03    2026-08-23
# 70          OH  collected_and_validated      2023-01-01    2026-07-31
# 74          OR                       ok      2025-07-01    2026-07-31
# 76          PA  collected_and_validated      2019-07-01    2026-07-31
# 78          RI  collected_and_validated      2019-09-01    2026-07-31
# 84          TN  collected_and_validated      2023-11-01    2026-07-31
# 92          VT  collected_and_validated      2024-01-01    2026-07-31
# 98          WV  collected_and_validated      2020-07-01    2026-08-22
# 100         WY      partially_collected      2021-09-01    2026-07-31
#
#                                                 reason  \
# 10   55 parsed reports; 0 failures. Details: C:\Use...
# 12   Staging corrects the legacy mapping: printed o...
# 14   Stored official history starts July 2024; earl...
# 16   Official lottery sportsbook tables group casin...
# 24   Retained official reports parsed with state-sp...
# 28   Handle uses all wagering activity while State ...
# 30   Legacy calculated totals remain classified as ...
# 32   Current detail archive starts January 2023; Se...
# 34   Only March-April 2025 statewide online figures...
# 36   FY22 workbook final two rows print July/August...
# 38   MGC consolidated monthly PDFs: Category 3 oper...
# 40   Archive pagination and older release titles ar...
# 42   Two native tribal reporting groups; operator s...
# 44   Retained official reports parsed with state-sp...
# 48   Retained official reports parsed with state-sp...
# 54   Retained official reports parsed with state-sp...
# 60   Retained official reports parsed with state-sp...
# 62   Sports handle is missing. The 98 retained spor...
# 66   Mobile-only win starts January 2020 in this ar...
# 68   Weekly cash-basis mobile handle/GGR; overlappi...
# 70   Retained official reports parsed with state-sp...
# 74   33 parsed reports; 0 failures. Details: C:\Use...
# 76   Staging replays original sports workbooks and ...
# 78   Retained official reports parsed with state-sp...
# 84   Current series is handle and privilege tax, no...
# 92   Monthly source reports January 2024 onward; tw...
# 98   Weekly periods remain as reported. Casino Reve...
# 100  Historical statewide summaries become operator...
#
#                                           official_url
# 10   https://spl.cde.state.co.us/artemis/revserials...
# 12   https://portal.ct.gov/dcp/gaming-division/gami...
# 14                https://dclottery.com/olg/financials
# 16   https://delottery.com/Sports-Lottery/Monthly-N...
# 24   https://irgc.iowa.gov/publications-reports/spo...
# 28   https://igb.illinois.gov/sports-wagering/sport...
# 30   https://www.in.gov/igc/publications/monthly-re...
# 32   https://www.kslottery.gov/publications/sports-...
# 34   https://khrc.ky.gov/newstatic_info.aspx/utils/...
# 36             https://lgcb.dps.louisiana.gov/reports/
# 38         https://massgaming.com/regulations/revenue/
# 40   https://www.mdgaming.com/maryland-sports-wager...
# 42   https://www.maine.gov/dps/gcu/sports-wagering/...
# 44   https://www.michigan.gov/mgcb/detroit-casinos/...
# 48   https://www.mgc.dps.mo.gov/SportsWagering/sw_f...
# 54                       https://ncgaming.gov/reports/
# 60    https://nhlottery.com/About-Us/Financial-Reports
# 62   https://www.njoag.gov/about/divisions-and-offi...
# 66   https://www.gaming.nv.gov/about-us/gaming-reve...
# 68               https://gaming.ny.gov/revenue-reports
# 70                     https://casinocontrol.ohio.gov/
# 74   https://www.oregonlottery.org/about/how-we-ope...
# 76   https://gamingcontrolboard.pa.gov/news-and-tra...
# 78   https://www.rilot.com/en-us/about-us/financial...
# 84                     https://www.tn.gov/swac/reports
# 92   https://liquorandlottery.vermont.gov/monthly-r...
# 98    https://business.wvlottery.com/resourcesPayments
# 100  https://gaming.wyo.gov/revenue-reports/financi...

# %%
availability = []
for state in states:
    stored = selected[selected["state_code"].eq(state)]
    rows = requested[requested["state_code"].eq(state)]
    note = ""
    if stored.empty:
        note = "No stored observations for this product"
    elif rows.empty:
        note = "No online periods wholly inside the dates at this frequency"
    elif rows["revenue"].isna().all():
        note = "Selected metric is missing or has unresolved source conflicts"
    availability.append({"state": state, "stored_frequencies": ", ".join(sorted(stored["frequency"].unique())),
                         "periods_in_selection": len(rows), "periods_with_values": rows["revenue"].notna().sum(), "note": note})
display(pd.DataFrame(availability))
# Out:
#    state stored_frequencies  periods_in_selection  periods_with_values  \
# 0     CO            monthly                    13                    0
# 1     CT            monthly                    19                   19
# 2     DC            monthly                    19                   18
# 3     DE                                        0                    0
# 4     IA            monthly                    19                    0
# 5     IL            monthly                    18                    0
# 6     IN            monthly                    19                   19
# 7     KS            monthly                    19                    0
# 8     KY            monthly                     2                    0
# 9     LA            monthly                    19                    0
# 10    MA            monthly                    19                   19
# 11    MD            monthly                    19                    0
# 12    ME            monthly                    19                    0
# 13    MI            monthly                    19                   19
# 14    MO            monthly                     8                    0
# 15    NC            monthly                    19                   19
# 16    NH            monthly                    19                   19
# 17    NJ            monthly                    19                   19
# 18    NV            monthly                    19                   19
# 19    NY             weekly                     0                    0
# 20    OH            monthly                    19                   19
# 21    OR            monthly                    13                   13
# 22    PA            monthly                    19                   19
# 23    RI            monthly                    19                   19
# 24    TN            monthly                    19                    0
# 25    VT            monthly                    19                    0
# 26    WV             weekly                     0                    0
# 27    WY            monthly                    19                   19
#
#                                                  note
# 0   Selected metric is missing or has unresolved s...
# 1
# 2
# 3             No stored observations for this product
# 4   Selected metric is missing or has unresolved s...
# 5   Selected metric is missing or has unresolved s...
# 6
# 7   Selected metric is missing or has unresolved s...
# 8   Selected metric is missing or has unresolved s...
# 9   Selected metric is missing or has unresolved s...
# 10
# 11  Selected metric is missing or has unresolved s...
# 12  Selected metric is missing or has unresolved s...
# 13
# 14  Selected metric is missing or has unresolved s...
# 15
# 16
# 17
# 18
# 19  No online periods wholly inside the dates at t...
# 20
# 21
# 22
# 23
# 24  Selected metric is missing or has unresolved s...
# 25  Selected metric is missing or has unresolved s...
# 26  No online periods wholly inside the dates at t...
# 27

# %% [markdown]
# ## 3. Inspect the selected state-period rows
# `reported_total` is a total printed in a regulator report.
# `operator_coverage_unverified` is the sum of **observed operators**, whose market coverage has not been proven.
# `missing_values` means at least one contributing row lacks the selected metric.
# `conflicting_sources` means retained reports disagree. No winner is assumed.
#
# Numbers from observed operators remain useful to inspect, but are not certified statewide totals.
# The source's row label may describe another retained financial column; inspect the report for the selected metric's definition.

# %%
table = requested.sort_values(["state_code", "period_start"]).reset_index(drop=True)
columns = ["state_code", "period_start", "period_end", "frequency", metric,
           "aggregation_source", "completeness", "operator_count", "reported_revenue_name"]
display(table[list(dict.fromkeys(columns))])

excluded = table[table["revenue"].isna()]
print(f"{len(excluded)} selected periods have no usable value; see the reason below.")
display(excluded[["state_code", "period_start", "completeness", "source_file"]])
# Out:
#     state_code period_start period_end frequency  gross_revenue  \
# 0           CO   2025-01-01 2025-01-31   monthly            NaN
# 1           CO   2025-02-01 2025-02-28   monthly            NaN
# 2           CO   2025-03-01 2025-03-31   monthly            NaN
# 3           CO   2025-04-01 2025-04-30   monthly            NaN
# 4           CO   2025-05-01 2025-05-31   monthly            NaN
# ..         ...          ...        ...       ...            ...
# 429         WY   2026-03-01 2026-03-31   monthly     1944149.68
# 430         WY   2026-04-01 2026-04-30   monthly     1852078.23
# 431         WY   2026-05-01 2026-05-31   monthly     1977424.41
# 432         WY   2026-06-01 2026-06-30   monthly     1409388.03
# 433         WY   2026-07-01 2026-07-31   monthly     2429096.43
#
#            aggregation_source    completeness  operator_count  \
# 0    official_statewide_total  missing_values               0
# 1    official_statewide_total  missing_values               0
# 2    official_statewide_total  missing_values               0
# 3    official_statewide_total  missing_values               0
# 4    official_statewide_total  missing_values               0
# ..                        ...             ...             ...
# 429  official_statewide_total  reported_total               5
# 430  official_statewide_total  reported_total               5
# 431  official_statewide_total  reported_total               5
# 432  official_statewide_total  reported_total               5
# 433  official_statewide_total  reported_total               5
#
#                   reported_revenue_name
# 0    Net Sports Betting Proceeds (NSBP)
# 1    Net Sports Betting Proceeds (NSBP)
# 2    Net Sports Betting Proceeds (NSBP)
# 3    Net Sports Betting Proceeds (NSBP)
# 4    Net Sports Betting Proceeds (NSBP)
# ..                                  ...
# 429                Gross Gaming Revenue
# 430                Gross Gaming Revenue
# 431                Gross Gaming Revenue
# 432                Gross Gaming Revenue
# 433                Gross Gaming Revenue
#
# [434 rows x 9 columns]
# 175 selected periods have no usable value; see the reason below.
#     state_code period_start    completeness  \
# 0           CO   2025-01-01  missing_values
# 1           CO   2025-02-01  missing_values
# 2           CO   2025-03-01  missing_values
# 3           CO   2025-04-01  missing_values
# 4           CO   2025-05-01  missing_values
# ..         ...          ...             ...
# 410         VT   2026-03-01  missing_values
# 411         VT   2026-04-01  missing_values
# 412         VT   2026-05-01  missing_values
# 413         VT   2026-06-01  missing_values
# 414         VT   2026-07-01  missing_values
#
#                                            source_file
# 0    data\raw\CO\2026-09-05\2a43b1ce4a8ac6721c892ea...
# 1    data\raw\CO\2026-09-05\97db774bfc0d227f0545638...
# 2    data\raw\CO\2026-09-05\103b8f1f51172dc5656656a...
# 3    data\raw\CO\2026-09-05\f124a2f5b483e9dbc3df837...
# 4    data\raw\CO\2026-09-05\6bbbb796c35cd6e84cf73d7...
# ..                                                 ...
# 410  data\raw\VT\2026-09-05\66aca0d01db6c827300d296...
# 411  data\raw\VT\2026-09-05\a6ebb7541c21f1ed2b43a41...
# 412  data\raw\VT\2026-09-05\cb578b5841c854046e22c71...
# 413  data\raw\VT\2026-09-05\548a8daa3294637e6e336b0...
# 414  data\raw\VT\2026-09-05\633cac05c441f62c84ecdd2...
#
# [175 rows x 4 columns]

# %%
# Missing observations are gaps, not zeros; preserve the source reporting grid.
missing_months = []
if frequency == "monthly":
    expected = pd.date_range(start, end, freq="MS")
    expected = expected[expected + pd.offsets.MonthEnd(0) <= end]
    for state in states:
        present = table.loc[table["state_code"].eq(state), "period_start"]
        for month in expected.difference(present):
            missing_months.append({"state": state, "missing_month": month.date()})
print("Absent monthly rows (may include pre-launch months or unavailable history):")
display(pd.DataFrame(missing_months, columns=["state", "missing_month"]))
missing_weeks = []
if frequency == "weekly":
    for state in states:
        source_dates = period_rows.loc[period_rows.state_code.eq(state) & period_rows.frequency.eq("weekly") & period_rows.channel.eq(channel), "period_start"].dropna()
        if source_dates.empty:
            print(f"{state}: no retained weekly anchor; expected coverage unknown.")
            continue
        anchor = source_dates.min()
        first = start + pd.Timedelta(days=(anchor - start).days % 7)
        expected = pd.date_range(first, end - pd.Timedelta(days=6), freq="7D")
        present = table.loc[table.state_code.eq(state), "period_start"]
        if not present.isin(expected).all():
            raise SystemExit(f"FAIL CLOSED: {state} observations do not follow the source seven-day grid.")
        for week in expected.difference(present):
            missing_weeks.append(dict(state=state, missing_week_start=week.date(), missing_week_end=(week + pd.Timedelta(days=6)).date()))
    print("Missing complete weeks on each source's seven-day grid (may include pre-launch or unavailable history):")
    display(pd.DataFrame(missing_weeks, columns=["state", "missing_week_start", "missing_week_end"]))

# %% [markdown]
# ## 4. View the trend
# Solid lines show published statewide totals. Dashed lines show observed-operator sums with unverified coverage.
# Missing values are gaps. No missing month is estimated.
# Weekly charts use a seven-day grid anchored to the source dates. Absent weeks break the line; the coverage table lists missing complete weeks in the selected window. Weeks are never allocated to months. An unknown anchor is shown as unknown coverage.

# %%
if table["revenue"].notna().any():
    fig, ax = plt.subplots(figsize=(10, 4))
    for (state, scope), group in table.groupby(["state_code", "aggregation_source"]):
        series = group.set_index("period_start")["revenue"].sort_index()
        if frequency == "monthly":
            series = series.reindex(pd.date_range(series.index.min(), series.index.max(), freq="MS"))
        elif frequency == "weekly":
            grid = pd.date_range(series.index.min(), series.index.max(), freq="7D")
            if not series.index.isin(grid).all():
                raise SystemExit(f"FAIL CLOSED: {state} has dates off its seven-day reporting grid.")
            series = series.reindex(grid)  # NaN breaks the line; no monthly allocation.
        official = scope == "official_statewide_total"
        label = state if official else f"{state} (observed operators; coverage unverified)"
        ax.plot(series.index, series / 1e6, label=label, linestyle="-" if official else "--")
    ax.set(title=f"{product}: {metric} ({frequency})", ylabel="USD millions", xlabel="Reporting period")
    ax.legend(fontsize=8)
    fig.tight_layout()
    plt.show()
else:
    print("No values to chart for this selection. Review coverage or choose another metric.")

# %% [markdown]
# ## 5. Year-over-year growth after definition review
# Read the relevant reports and metric notes for the entire selected window. The table below lists states with mechanically eligible year-over-year pairs, labeled **pending analyst review**. Add reviewed states to `growth_states_reviewed` above only after you confirm the comparison is appropriate.
#
# YoY estimates are calculated only for states explicitly listed in `growth_states_reviewed`. An empty list (or `None`) skips growth entirely and does **not** approve all selected states.
#
# The mechanical eligibility check requires published statewide monthly totals, matching labels, the same month a year earlier, both periods inside the selected window, and a positive prior value. Partial launch periods need review too.

# %%
def _yoy_pairs(official: pd.DataFrame) -> pd.DataFrame:
    columns = ["state_code", "period_start", "revenue", "prior_revenue", "yoy_pct"]
    if frequency != "monthly" or official.empty:
        return pd.DataFrame(columns=columns)
    prior = official[["state_code", "period_start", "revenue", "reported_revenue_name"]].copy()
    prior["period_start"] = prior["period_start"] + pd.DateOffset(years=1)
    prior = prior.rename(columns={"revenue": "prior_revenue"})
    matches = official.merge(
        prior, on=["state_code", "period_start", "reported_revenue_name"], validate="one_to_one"
    )
    matches = matches[matches["prior_revenue"].gt(0)]
    matches["yoy_pct"] = 100 * (matches["revenue"] / matches["prior_revenue"] - 1)
    return matches[columns]


official_candidates = table[
    table["completeness"].eq("reported_total") & table.state_code.isin(states)
].copy()
candidate_pairs = _yoy_pairs(official_candidates)
if candidate_pairs.empty:
    print("No mechanically eligible year-over-year pairs among selected states.")
else:
    pending = (
        candidate_pairs.groupby("state_code", as_index=False)
        .agg(pair_count=("period_start", "size"))
        .assign(review_status="pending analyst review")
        .sort_values("state_code")
    )
    display(pending)
    print(
        "Pending analyst review: mechanically eligible pairs only. "
        "No YoY estimate is calculated until a state is listed in growth_states_reviewed."
    )

if growth_states_reviewed:
    reviewed_official = official_candidates[official_candidates.state_code.isin(growth_states_reviewed)]
    yoy = _yoy_pairs(reviewed_official)
    display(yoy.groupby("state_code", as_index=False).tail(1))
    if yoy.empty:
        print("No qualifying year-over-year pairs for reviewed states. No comparison has been estimated.")
else:
    print("No states in growth_states_reviewed. No YoY comparison has been estimated.")
# Out:
#    state_code period_start      revenue  prior_revenue     yoy_pct
# 6          MA   2026-07-01  66530607.93    48644427.36   36.769228
# 13         MI   2026-07-01  43355598.93    34075975.75   27.232157
# 20         NC   2026-07-01  63215572.00    22679993.00  178.728358
# 27         NH   2026-07-01   7313470.00     4880547.00   49.849392
# 34         NV   2026-07-01  37302000.00    30318000.00   23.035820
# 41         OH   2026-07-01  66527048.00    58935481.00   12.881149
# 42         OR   2026-07-01  10424591.00     5868825.00   77.626544
# 49         PA   2026-07-01  62508267.77    49504519.26   26.267801
# 56         RI   2026-07-01   2654411.00     1480027.00   79.348823
# 63         WY   2026-07-01   2429096.43     1372017.91   77.045534

# %% [markdown]
# ## 6. Trace a number to its source
# Choose a state and period below. This displays the original operator and statewide observations,
# including conflicting versions and legacy derived totals. It never sums these raw rows together.
# Open `source_file` relative to the repository; Illinois references two files separated by `|`.

# %%
trace_state = states[0]
trace_period = None  # e.g. "2026-07-01"; None selects this state's latest displayed period
state_rows = table[table["state_code"].eq(trace_state)]
if trace_period is None and not state_rows.empty:
    trace_period = state_rows["period_start"].max().date().isoformat()
trace = selected[selected["state_code"].eq(trace_state) & selected["period_start"].eq(trace_period)]
trace_columns = ["operator", "row_type", metric, "report_status", "reported_revenue_name",
                 "source_url", "source_file", "source_sha256", "retrieved_at_utc"]
with pd.option_context("display.max_colwidth", None):
    display(trace[trace_columns])
# Out:
#         operator                  row_type  gross_revenue report_status  \
# 17736  STATEWIDE  official_statewide_total            NaN      reported
#
#                     reported_revenue_name  \
# 17736  Net Sports Betting Proceeds (NSBP)
#
#                                                                                        source_url  \
# 17736  https://spl.cde.state.co.us/artemis/revserials/rev14111internet/rev14111202602internet.pdf
#
#                                                                                                               source_file  \
# 17736  data\raw\CO\2026-09-05\c2ecd2958624c18e00bca87f650cfc01a4b7710485761cac1621d1f059088655_rev14111202602internet.pdf
#
#                                                           source_sha256  \
# 17736  c2ecd2958624c18e00bca87f650cfc01a4b7710485761cac1621d1f059088655
#
#                        retrieved_at_utc
# 17736  2026-09-05T01:38:14.171704+00:00

# %% [markdown]
# ## Optional: export this table
# This writes only the displayed analysis table to CSV. It does not update SQLite or download reports.
# Set `export_csv = True` and run this cell when you want the file.

# %%
export_csv = False
export_path = ROOT / "data" / "processed" / "selected_revenue.csv"
if export_csv:
    export_path.parent.mkdir(parents=True, exist_ok=True)
    table.to_csv(export_path, index=False)
    print(export_path)

# %% [markdown]
# ## Interpret the selected trend before attributing it
# This notebook measures the selected state metric; statewide revenue alone cannot establish FanDuel share or hold. Open 31 for a report walkthrough, 91 for MA's matched Accrual Win/handle/share/hold decomposition, 92 for exploratory sportsbook coverage, and 93 for MI Gross Receipts/share.
#
# Use the trace below for unusual values. Duplicate source versions remain visible; matching values do not prove definitions are comparable across states. Growth eligibility and the existing `growth_states_reviewed` choice remain unchanged.

# %%
trace = selected[
    pd.to_datetime(selected.period_start).ge(start)
    & pd.to_datetime(selected.period_end).le(end)
    & selected.frequency.eq(frequency) & selected.channel.eq(channel)
].copy()
trace["selected_metric_missing"] = trace[metric].isna()
trace["multiple_source_versions"] = trace.duplicated(
    ["state_code", "period_start", "period_end", "operator", "row_type", "channel", "frequency"], keep=False)
print("Missing/negative selected values and multiple retained versions (review, not automatic errors):")
display(trace[trace.selected_metric_missing | trace[metric].lt(0) | trace.multiple_source_versions][
    ["state_code", "period_start", "operator", metric, "selected_metric_missing",
     "multiple_source_versions", "source_url", "source_file", "source_sha256"]])
